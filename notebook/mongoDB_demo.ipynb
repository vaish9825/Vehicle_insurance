# %%
import sys
print(sys.executable)
# !pip install pandas
# Out:
# /Users/vaishnavisureshwaghmare/miniconda3/envs/vehicle/bin/python
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting numpy>=1.22.4 (from pandas)
#   Downloading numpy-2.2.6-cp310-cp310-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/vaishnavisureshwaghmare/miniconda3/envs/vehicle/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2026.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Users/vaishnavisureshwaghmare/miniconda3/envs/vehicle/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp310-cp310-macosx_11_0_arm64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 1.7 MB/s  0:00:06 eta 0:00:01
# Downloading numpy-2.2.6-cp310-cp310-macosx_14_0_arm64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 673.6 kB/s  0:00:07m0:00:0100:01
# Using cached pytz-2026.2-py2.py3-none-any.whl (510 kB)
# Using cached tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]2m3/4 [pandas]
# Successfully installed numpy-2.2.6 pandas-2.3.3 pytz-2026.2 tzdata-2026.2

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.17.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (10 kB)
# Collecting dnspython<3.0.0,>=2.6.1 (from pymongo)
#   Using cached dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading pymongo-4.17.0-cp310-cp310-macosx_11_0_arm64.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 820.0/820.0 kB 565.4 kB/s  0:00:01eta 0:00:01
# Using cached dnspython-2.8.0-py3-none-any.whl (331 kB)
# Installing collected packages: dnspython, pymongo
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pymongo]m1/2 [pymongo]
# Successfully installed dnspython-2.8.0 pymongo-4.17.0

# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
# data

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://vsw985_db_user:duJhceRH47D4yzEX@cluster0.qqavvs5.mongodb.net/?appName=Cluster0"

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
# Uploading data to MongoDB
rec = collection.insert_many(data)
